# %% [markdown]
# <a href="https://colab.research.google.com/github/Yilap88/Academic-Notes/blob/main/Statistics_for_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import time

repo_path = "/content/turepo"
os.chdir(repo_path)

while True:
    os.system("git add .")
    os.system('git commit -m "Auto guardado desde Colab"')
    os.system("git push origin main")
    time.sleep(600)  # guarda cada 10 minutos
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2401726141.py in <cell line: 0>()
#       3
#       4 repo_path = "/content/turepo"
# ----> 5 os.chdir(repo_path)
#       6
#       7 while True:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/turepo'
