# %% [markdown]
# <a href="https://colab.research.google.com/github/Yilap88/Academic-Notes/blob/main/Statistics_for_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## STATISTICS FOR DATA ANALYSIS
#
# This is a review of some basic statistical topics focused on:
#
# - Inferential statistics
# - Population median
# - Median standard error
# - Confidence intervals
# - Statistical Bias and Lies

# %% [markdown]
# ### Inferential Statistics
#
# In this section, we will approach the basic concepts of populations and sample data, and explore how distributions and their characteristics (such as the median and standard error) can be used to draw inferential conclusions.

# %%
# Inferential Statistics
